# %%
from google.colab import files
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1d26e31f-8d2d-4405-bc1f-3656df9fbdc6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d26e31f-8d2d-4405-bc1f-3656df9fbdc6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_description = {
    'Sütun Adı': [
        'ISO3',
        'Country',
        'Continent',
        'Hemisphere',
        'Human Development Groups',
        'UNDP Developing Regions',
        'HDI Rank (2021)',
        'GII Rank (2021)',
        'Gender Inequality Index from 1990 to 2021'
    ],
    'Açıklama': [
        'Ülke veya bölge için kullanılan 3 harfli uluslararası kod.',
        'Ülke veya bölgenin adı.',
        'Ülkenin veya bölgenin bulunduğu kıtanın adı.',
        'Ülkenin bulunduğu yarımküre (Kuzey veya Güney).',
        'İnsan gelişimi grupları.',
        'Birleşmiş Milletler Kalkınma Programı tarafından tanımlanan gelişmekte olan bölgeler.',
        '2021 yılı itibarıyla İnsan Gelişimi Endeksi sıralaması.',
        '2021 yılı itibarıyla Cinsiyet Eşitsizliği Endeksi sıralaması.',
        '1990 yılından 2021 yılına kadar olan Cinsiyet Eşitsizliği Endeksi verileri.'
    ]
}

# %%
df_description = pd.DataFrame(df_description)
print(df_description.to_string(index=False))
# Out:
#                                 Sütun Adı                                                                              Açıklama
#                                      ISO3                            Ülke veya bölge için kullanılan 3 harfli uluslararası kod.
#                                   Country                                                               Ülke veya bölgenin adı.
#                                 Continent                                          Ülkenin veya bölgenin bulunduğu kıtanın adı.
#                                Hemisphere                                       Ülkenin bulunduğu yarımküre (Kuzey veya Güney).
#                  Human Development Groups                                                              İnsan gelişimi grupları.
#                   UNDP Developing Regions Birleşmiş Milletler Kalkınma Programı tarafından tanımlanan gelişmekte olan bölgeler.
# ...

# %%
df = pd.read_csv('Gender Inequality Index.csv')
df.head()
# Out:
#   ISO3               Country Continent           Hemisphere  \
# 0  AFG           Afghanistan      Asia  Northern Hemisphere
# 1  AGO                Angola    Africa  Southern Hemisphere
# 2  ALB               Albania    Europe  Northern Hemisphere
# 3  AND               Andorra    Europe  Northern Hemisphere
# 4  ARE  United Arab Emirates      Asia  Northern Hemisphere
#
#   Human Development Groups UNDP Developing Regions  HDI Rank (2021)  \
# 0                      Low                      SA            180.0
# 1                   Medium                     SSA            148.0
# 2                     High                     ECA             67.0
# 3                Very High                     NaN             40.0
# 4                Very High                      AS             26.0
#
#    GII Rank (2021)  Gender Inequality Index (1990)  \
# 0            167.0                             NaN
# 1            136.0                           0.725
# ...

# %%
df.tail()
# Out:
#     ISO3       Country Continent           Hemisphere  \
# 190  WSM         Samoa   Oceania  Southern Hemisphere
# 191  YEM         Yemen      Asia  Northern Hemisphere
# 192  ZAF  South Africa    Africa  Southern Hemisphere
# 193  ZMB        Zambia    Africa  Southern Hemisphere
# 194  ZWE      Zimbabwe    Africa  Southern Hemisphere
#
#     Human Development Groups UNDP Developing Regions  HDI Rank (2021)  \
# 190                     High                     EAP            111.0
# 191                      Low                      AS            183.0
# 192                     High                     SSA            109.0
# 193                   Medium                     SSA            154.0
# 194                   Medium                     SSA            146.0
#
#      GII Rank (2021)  Gender Inequality Index (1990)  \
# 190             99.0                             NaN
# 191            170.0                             NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 40 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ISO3                            195 non-null    object
#  1   Country                         195 non-null    object
#  2   Continent                       195 non-null    object
#  3   Hemisphere                      195 non-null    object
#  4   Human Development Groups        191 non-null    object
#  5   UNDP Developing Regions         151 non-null    object
#  6   HDI Rank (2021)                 191 non-null    float64
#  7   GII Rank (2021)                 170 non-null    float64
#  8   Gender Inequality Index (1990)  128 non-null    float64
#  9   Gender Inequality Index (1991)  128 non-null    float64
#  10  Gender Inequality Index (1992)  128 non-null    float64
#  11  Gender Inequality Index (1993)  128 non-null    float64
# ...

# %%
df.describe()
# Out:
#        HDI Rank (2021)  GII Rank (2021)  Gender Inequality Index (1990)  \
# count       191.000000       170.000000                      128.000000
# mean         95.811518        85.376471                        0.487578
# std          55.307333        49.210206                        0.192331
# min           1.000000         1.000000                        0.090000
# 25%          48.500000        43.250000                        0.319500
# 50%          96.000000        85.500000                        0.515000
# 75%         143.500000       127.750000                        0.659000
# max         191.000000       170.000000                        0.811000
#
#        Gender Inequality Index (1991)  Gender Inequality Index (1992)  \
# count                      128.000000                      128.000000
# mean                         0.485078                        0.481766
# std                          0.191521                        0.192052
# ...

# %%
df.isnull().sum()
# Out:
# ISO3                               0
# Country                            0
# Continent                          0
# Hemisphere                         0
# Human Development Groups           4
# UNDP Developing Regions           44
# HDI Rank (2021)                    4
# GII Rank (2021)                   25
# Gender Inequality Index (1990)    67
# Gender Inequality Index (1991)    67
# Gender Inequality Index (1992)    67
# Gender Inequality Index (1993)    67
# Gender Inequality Index (1994)    67
# Gender Inequality Index (1995)    65
# Gender Inequality Index (1996)    65
# Gender Inequality Index (1997)    65
# Gender Inequality Index (1998)    59
# Gender Inequality Index (1999)    54
# Gender Inequality Index (2000)    51
# Gender Inequality Index (2001)    46
# Gender Inequality Index (2002)    45
# Gender Inequality Index (2003)    42
# Gender Inequality Index (2004)    39
# Gender Inequality Index (2005)    36
# Gender Inequality Index (2006)    33
# ...

# %%
countries = df['Country'].unique()
print(f"Veri setinde toplam {len(countries)} farklı ülke var.")
# Out:
# Veri setinde toplam 195 farklı ülke var.

# %%
print("Ülkeler:")
for country in countries:
    print(country)
# Out:
# Ülkeler:
# Afghanistan
# Angola
# Albania
# Andorra
# United Arab Emirates
# Argentina
# Armenia
# Antigua and Barbuda
# Australia
# Austria
# Azerbaijan
# Burundi
# Belgium
# Benin
# Burkina Faso
# Bangladesh
# Bulgaria
# Bahrain
# Bahamas
# Bosnia and Herzegovina
# Belarus
# Belize
# Bolivia
# Brazil
# Barbados
# Brunei
# Bhutan
# Botswana
# Central African Republic
# Canada
# Switzerland
# Chile
# China
# Ivory Coast
# Cameroon
# The Democratic Republic of the Congo
# Congo
# Colombia
# Comoros
# Cabo Verde
# Costa Rica
# Cuba
# Cyprus
# Czechia
# Germany
# Djibouti
# Dominica
# Denmark
# Dominican Republic
# Algeria
# Ecuador
# Egypt
# Eritrea
# Spain
# Estonia
# Ethiopia
# Finland
# Fiji
# France
# Micronesia
# Gabon
# United Kingdom
# Georgia
# Ghana
# Guinea
# Gambia
# Guinea-Bissau
# Equatorial Guinea
# Greece
# Grenada
# Guatemala
# Guyana
# Hong Kong
# Honduras
# Croatia
# Haiti
# Hungary
# Indonesia
# India
# Ireland
# Iran
# Iraq
# Iceland
# Israel
# Italy
# Jamaica
# ...

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='Gender Inequality Index (2021)', y='Country', data=df.sort_values(by='Gender Inequality Index (2021)', ascending=False).head(10)) #“ascending = false” → azalan şekilde sıralama yapılmasını sağlar.
plt.title("2021 Yılında En Yüksek Cinsiyet Eşitsizliği Olan 10 Ülke")
plt.xlabel("Cinsiyet Eşitsizliği Endeksi (2021)")
plt.ylabel("Ülkeler")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='Gender Inequality Index (2021)', y='Country', data=df.sort_values(by='Gender Inequality Index (2021)').head(10))
plt.title("2021 Yılında En Düşük Cinsiyet Eşitsizliği Olan 10 Ülke")
plt.xlabel("Cinsiyet Eşitsizliği Endeksi (2021)")
plt.ylabel("Ülkeler")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(y='Human Development Groups', data=df, order=df['Human Development Groups'].value_counts().index)
plt.title("İnsan Gelişimi Gruplarına Göre Ülke Sayısı")
plt.xlabel("Ülke Sayısı")
plt.ylabel("İnsan Gelişimi Grupları")
plt.show()

# %%
ulke1 = 'Turkey'
ulke1_verisi = df[df['Country'] == ulke1]
yillar = ['Gender Inequality Index (' + str(year) + ')' for year in range(1990, 2022)]
gii_degerleri = ulke1_verisi[yillar].values.flatten()
plt.figure(figsize=(10, 5))
plt.plot(yillar, gii_degerleri, marker='o')
plt.title(ulke1 + " Cinsiyet Eşitsizliği Endeksi (1990-2021)")
plt.xlabel("Yıllar")
plt.ylabel("Cinsiyet Eşitsizliği Endeksi (GII)")
plt.grid()
plt.xticks(rotation=45)
plt.show()

# %%
ulke2 = 'Norway'
ulke2_verisi = df[df['Country'] == ulke2]
yillar = ['Gender Inequality Index (' + str(year) + ')' for year in range(1990, 2022)]
gii_degerleri = ulke2_verisi[yillar].values.flatten()
plt.figure(figsize=(10, 5))
plt.plot(yillar, gii_degerleri, marker='o')
plt.title(ulke2 + " Cinsiyet Eşitsizliği Endeksi (1990-2021)")
plt.xlabel("Yıllar")
plt.ylabel("Cinsiyet Eşitsizliği Endeksi (GII)")
plt.grid()
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.bar(df['Continent'], df['Gender Inequality Index (1990)'])
plt.title("Kıtalar Bazında Cinsiyet Eşitsizliği Endeksi (1990)")
plt.xlabel("Kıtalar")
plt.ylabel("Cinsiyet Eşitsizliği Endeksi (1990)")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.bar(df['Continent'], df['Gender Inequality Index (2021)'])
plt.title("Kıtalar Bazında Cinsiyet Eşitsizliği Endeksi (2021)")
plt.xlabel("Kıtalar")
plt.ylabel("Cinsiyet Eşitsizliği Endeksi (2021)")
plt.show()
